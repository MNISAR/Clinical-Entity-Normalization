# %%
import pandas as pd
from reading_data import reading_files
from create_dataset import create_dataset

# %%
base_dir = "train"
data, CUI = reading_files(base_dir)
# Out:
# Total number of files:  50
# Total CUIs:  2331
# Total Data:  50

# %%
d = create_dataset(data)

# %%
d
# Out:
#            cui                                  original_sentence  \
# 0     C0564823  054478430 ELMVH 79660638 1835979 12/11/2005 12...
# 1     C0030193  054478430 ELMVH 79660638 1835979 12/11/2005 12...
# 2     C0018681  054478430 ELMVH 79660638 1835979 12/11/2005 12...
# 3     C0204688  054478430 ELMVH 79660638 1835979 12/11/2005 12...
# 4     C0030049  054478430 ELMVH 79660638 1835979 12/11/2005 12...
# ...        ...                                                ...
# 6787  C2316867  989519730 WGH 4708487 265076 4927849 05/09/200...
# 6788  C0002771  989519730 WGH 4708487 265076 4927849 05/09/200...
# 6789  C0229299  989519730 WGH 4708487 265076 4927849 05/09/200...
# 6790  C2316867  989519730 WGH 4708487 265076 4927849 05/09/200...
# 6791  C0002771  989519730 WGH 4708487 265076 4927849 05/09/200...
#
#                                         masked_sentence            mention  \
# 0     054478430 ELMVH 79660638 1835979 12/11/2005 12...     Right LE pain
# ...

# %%
CUI
# Out:
# {'C0564823': {(0, 'R leg pain'), (0, 'Right LE pain')},
#  'C0030193': {(0, 'Pain'),
#   (0, 'pain'),
#   (0, 'painful'),
#   (0, 'the pain'),
#   (1, 'The pain'),
#   (1, 'pain'),
#   (2, 'pain'),
#   (3, 'pain'),
#   (6, 'pain'),
#   (6, 'that pain'),
#   (7, 'pain'),
#   (7, 'the patient &apos;s pain'),
#   (9, 'The pain'),
#   (9, 'the pain'),
#   (14, 'Pain'),
#   (18, 'pain'),
#   (21, 'pain'),
#   (26, 'pain'),
#   (30, 'pain'),
#   (30, 'the pain'),
#   (31, 'Pain'),
#   (33, 'Pain'),
#   (33, 'pain'),
#   (34, 'The patient &apos;s pain'),
#   (34, 'his pain'),
#   (34, 'pain'),
#   (35, 'pain'),
#   (35, 'the pain'),
#   (42, 'pain'),
#   (42, 'painful'),
#   (43, 'The pain'),
#   (45, 'pain'),
#   (46, 'Her pain'),
#   (46, 'the pain'),
#   (46, 'this pain'),
#   (49, 'pain')},
#  'C0018681': {(0, 'Headache'),
#   (13, 'Headache'),
#   (13, 'headache'),
#   (24, 'headache'),
#   (34, 'headache'),
#   (36, 'headache'),
#   (37, 'headache')},
# ...
