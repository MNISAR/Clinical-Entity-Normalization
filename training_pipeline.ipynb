# %%
# !pip install transformers

# !git clone https://github.com/MNISAR/Clinical-Entity-Normalization.git
# !mv ./Clinical-Entity-Normalization/train ./train
# !mv ./Clinical-Entity-Normalization/testing ./testing
# !rm -r ./Clinical-Entity-Normalization
# !wget https://github.com/MNISAR/Clinical-Entity-Normalization/raw/creating_dataset/reading_data.py
# !wget https://github.com/MNISAR/Clinical-Entity-Normalization/raw/creating_dataset/create_dataset.py

# %%
import tensorflow as tf
import torch
from transformers import BertTokenizer
from tqdm import tqdm
from sklearn import preprocessing

if torch.cuda.is_available():    
    device = torch.device("cuda")
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")

# %%
class config:
    TRAIN_PATH = "./train"
    MAX_LEN = 64
    TOKENIZER = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)
    BATCH_SIZE = 32
    EPOCHS = 10

# %%
from reading_data import reading_files, reading_files_test
from create_dataset import create_dataset
from UMLS_methods import *

# %%
# load training data
train_data, CUI, iCUI = reading_files("C:/Users/monil/Desktop/BMI 598 - NLP/Project/Clinical-Entity-Normalization/train")
train_df = create_dataset(train_data)
### removing CUIs from dataset that have only one mentions
train_single_cui = []
for cui, mention in CUI.items():
    if len(mention) == 1:
        train_single_cui.append(cui)
# Out:
# Total number of files:  50
# Total CUIs:  2331
# Total Data:  50

# %%
CUI
# Out:
# {'C0564823': {'R leg pain', 'Right LE pain'},
#  'C0030193': {'Her pain',
#   'Pain',
#   'The pain',
#   'The patient &apos;s pain',
#   'his pain',
#   'pain',
#   'painful',
#   'that pain',
#   'the pain',
#   'the patient &apos;s pain',
#   'this pain'},
#  'C0018681': {'Headache', 'headache'},
#  'C0204688': {'Her temperature',
#   'His temperature',
#   'T',
#   'Temp',
#   'Temperature',
#   'The patient &apos;s temperature',
#   'a temperature',
#   'his temperature',
#   'temp',
#   'temperature'},
#  'C0030049': {'OXYCODONE', 'Oxycodone', 'the Oxycodone'},
#  'CUI-less': {'2 liters',
#   '2L',
#   '4L',
#   'A work up',
#   'AH',
#   'All',
#   'Associated medical problems',
#   'ER',
#   'Enteric coated',
#   'HEENT exam',
#   'HEENT examination',
#   'ND',
#   'NEPHRO-VIT RX',
#   'Neutra-Phos',
#   'No acute distress',
#   'Os-Cal',
#   'ROBITUSSIN',
#   'ROMI',
#   'RR',
#   'SLOW REL.',
#   'SLOW RELEASE',
#   'SR',
#   'SS',
#   'SUSTAINED RELEASE',
#   'Study',
#   'TIB',
#   'TLC',
#   'Thad lesion',
#   'The head , eyes , ears , nose , throat and neck examinations',
#   'The head , eyes , ears , nose , throat exam',
#   'The head , eyes , ears , nose , throat examination',
#   'The head , eyes , ears , nose and throat examination',
#   'The patient &apos;s workup up',
#   'This study',
#   'Trauma series',
#   'Work up',
#   'XL',
#   'aggressive',
#   'another',
#   'apparent',
#   'associated mesenteric stranding',
#   'atraumatic',
#   'bilious material',
#   'blood pressure control',
#   'cold',
#   'comp arison film',
#   'continuity equation',
#   'deep tissue thread',
#   'direct pressure to the point',
#   'endothelialitis',
#   'fairly',
#   'fever greater than 101',
#   'further',
#   'further invasive measures',
#   'grade IV',
#   'greater afterload reduction',
#   'h pupils e',
#   'head , eyes , ears , nose and throat exam',
#   'heart rate control',
#   'her HEENT examination',
#   'her Os-Cal',
#   'her routine care',
#   'heterogenous enhancing',
#   'hyperdense and heterogenously enhancing',
#   'left-to-left filling',
#   'micro',
#   'moderate',
#   'multiple medical problems',
#   'near complete',
#   'no acute distress',
#   'no gross evidence seating in the abdominal wall',
#   'noncompressible',
#   'noxious stimuli',
#   'other abnormalities',
#   'pain in mental status',
#   'preference',
#   'quite',
#   'related enhancement',
#   'remarkable findings',
#   'right f',
#   's . Coum',
#   'sialagogue',
#   'some effacement of the sulci',
#   'somewhat',
#   'still',
#   'stranding along the pancreas',
#   'study',
#   'subtle',
#   'testing',
#   'the studies',
#   'the test',
#   'these tests',
#   'this test',
#   'three liters',
#   'too low',
#   'trial',
#   'trials',
#   'two units',
#   'up to the knees',
#   'usual',
#   'very poor effort',
#   'w / u',
#   'wide',
#   'work up',
#   'work-up',
#   'workup'},
#  'C0262580': {'NKA', 'No Known Allergies'},
#  'C0011849': {'DIABETES MELLITUS',
#   'DM',
#   'Diabetes mellitus',
#   'diabetes',
#   'diabetes mellitus',
#   'his diabetes mellitus'},
#  'C0554740': {'Pelvis XR'},
#  'C0033213': {'problems', 'this problem'},
#  'C1261311': {'a steroid injection'},
#  'C0028643': {'numb', 'numbness'},
#  'C3714552': {'her weakness', 'weakness'},
#  'C0015967': {'FEVER',
#   'a fever',
#   'a high temperature',
#   'any fever',
#   'fever',
#   'fevers',
#   'the patient &apos;s fever'},
#  'C0027497': {'any nausea', 'nausea'},
#  'C0042963': {'emesis', 'vomiting'},
#  'C0011991': {'diarrhea'},
#  'C0008031': {'CP',
#   'Chest Pain',
#   'Chest pain',
#   'chest pain',
#   'the chest pain'},
#  'C0042024': {'urinary incontinence'},
#  'C0278008': {'any changes in bowel habits'},
#  'C0011860': {'Non insulin dependent diabetes mellitus',
#   'Non-insulin dependent diabetes mellitus',
#   'Non-insulin-requiring diabetes mellitus',
#   'adult onset diabetes mellitus',
#   'non insulin dependent diabetes mellitus',
#   'non-insulin dependent diabetes mellitus',
#   'noninsulin dependent diabetes mellitus'},
#  'C0020443': {'HYPERCHOLESTEROLEMIA',
#   'High Cholesterol',
#   'hyperchol',
#   'hypercholesterolemia'},
#  'C0025598': {'Metformin'},
#  'C0678181': {'ZOCOR', 'Zocor', 'his zocor'},
#  'C0002771': {'His pain medication',
#   'analgesics',
#   'her pain medication',
#   'pain medications',
#   'pain regimen'},
#  'C0277797': {'Afebrile', 'afebrile'},
#  'C0523807': {'02 sat',
#   'O2 sat',
#   'O2 saturation',
#   'O2sat',
#   'Pox',
#   'Sat',
#   'The oxygen saturation',
#   'an oxygen saturation',
#   'his oxygen saturations',
#   'his saturations',
#   'oxygen saturation',
#   'oxygen saturations',
#   'satting',
#   'saturation'},
#  'C0018674': {'head trauma'},
#  'C0240962': {'scleral icterus'},
#  'C0497156': {'adenopathy', 'lymphadenopathy'},
#  'C0018808': {'cardiac murmurs',
#   'heart murmur',
#   'murmur',
#   'murmurs',
#   'with a hys'},
#  'C0232267': {'rub', 'rubs'},
#  'C0232200': {'gallop', 'gallops'},
#  'C0520960': {'NT', 'non-tender', 'nontender'},
#  'C1265602': {'masses'},
#  'C4075263': {'organomegaly'},
#  'C0010520': {'cyanosis'},
#  'C0149651': {'clubbing'},
#  'C0013604': {'DISC',
#   'atien',
#   'edema',
#   'interstitial edema',
#   'signs of edema'},
#  'C0577305': {'lesions', 'multiple|lesions', 'pariet'},
#  'C0015230': {'The rash', 'rash', 'rashes'},
#  'C0027853': {'A neurologic work-up',
#   'A neurological examination',
#   'His neurological examination',
#   'Neurologic examination',
#   'Neurological exam',
#   'Neurological examination',
#   'The neurological examination',
#   'neuro w / u',
#   'neurological examination',
#   'neurological|examination'},
#  'C0422926': {'Straight leg raise test'},
#  'C1446409': {'Positive', 'positive'},
#  'C0204480': {'Psychiatric examination', 'full Psychiatric evaluation'},
#  'C0575447': {'lumbar tenderness'},
#  'C1562820': {'Point tenderness', 'point tenderness'},
#  'C0177803': {'An MRI of the spine', 'Spien MRI'},
#  'C0745283': {'an infectious process'},
#  'C1176468': {'ESR',
#   'Erythrocyte sedimentation rate',
#   'Sed rate',
#   'erythrocyte sedimentation rate'},
#  'C0201657': {'CPR'},
#  'C1135276': {'supplemental oxygen'},
#  'C3494658': {'pneumoboots'},
#  'C0728963': {'Lovenox', 'lovenox'},
#  'C2585945': {'DVT prophylaxis'},
#  'C1443473': {'her chronic pain management'},
#  'C0027409': {'his narcotics', 'narcotics'},
#  'C0038999': {'distended', 'swelling', 'the swelling'},
#  'C0012621': {'discharge', 'drainage'},
#  'C3543005': {'The incision', 'the incisions', 'your incision'},
#  'C0000970': {'ACETAMINOPHEN'},
#  'C0699142': {'TYLENOL', 'Tylenol'},
#  'C0282139': {'COLACE', 'Colace', 'ously'},
#  'C0243237': {'DOCUSATE SODIUM'},
#  'C0235195': {'sedated', 'sedation'},
#  'C0442802': {'excesive'},
#  'C0728797': {'FLEXERIL', 'Flexeril'},
#  'C0125988': {'CYCLOBENZAPRINE HCL'},
#  'C0949766': {'PT',
#   'Physical Therapy',
#   'physical therapy',
#   'physical|therapy'},
#  'C2959422': {'hip Xray'},
#  'C0205090': {'R', 'RIGHT', 'Right', 'both', 'kness', 'right'},
#  'C0024031': {'low back pain'},
#  'C0205082': {'ension', 'high grade', 'ith se', 'severe', 'severely'},
#  'C0332271': {'is with s', 'worsening'},
#  'C0230415': {'RIGHT LOWER EXTREMITY',
#   'RLE',
#   'right leg',
#   'right lower extremity'},
#  'C4509826': {'shock like intensity'},
#  'C2316867': {'PO', 'oral', 'p.o.', 'po'},
#  'C0489633': {'The review of systems', 'review of systems'},
#  'C0205197': {'detailed'},
#  'C2364135': {'discomfort', 'the patient &apos;s discomfort', 'uncomfortable'},
#  'C0031809': {'0 ; heart r',
#   'An examination',
#   'Exam',
#   'Examination',
#   'On physical examination',
#   'PE',
#   'Physical examination',
#   'The physical examination',
#   'ate and rhy',
#   'elevation o',
#   'exam',
#   'examination',
#   'noted to be',
#   'physical exam',
#   'physical examination',
#   'the physical examination'},
#  'C1995000': {'back'},
#  'C4281768': {'L4/5 facet'},
#  'C0443285': {'enhancement'},
#  'C0222679': {'facet'},
#  'C0020564': {'hypertrophic', 'hypertrophy'},
#  'C0205250': {'elevated', 'high', 's pulse ,'},
#  'C2945599': {'MED', 'gentle', 'mild', 'mildly', 'veno'},
#  'C0030797': {'pelvis'},
#  'C0442212': {'AP'},
#  'C0043303': {'films'},
#  'C0524470': {'R hip', 'right hip'},
#  'C0278138': {'mild pain'},
#  'C0013216': {', b.i.d. ,',
#   'His medications',
#   'ISPEHBREUN',
#   'MEDICATIONS',
#   'Medications',
#   'his medications',
#   'medication',
#   'medications',
#   'the patient &apos;s medications',
#   'uded Coumad'},
#  'C0442519': {'at home', 'home'},
#  'C0699203': {'Motrin', 'motrin'},
#  'C0593507': {'advil'},
#  'C0332575': {'redness'},
#  'C0205217': {'augmented', 'increased'},
#  'C0001339': {'ACUTE PANCREATITIS', 'acute pancreatitis'},
#  'C0017168': {'GASTROESOPHAGEAL REFLUX DISEASE',
#   'GERD',
#   'gastroesophageal reflux disease'},
#  'C0000737': {'ABDOMINAL PAIN',
#   'The patient &apos;s abdominal pain',
#   'abdominal pain',
#   'belly pain',
#   'his abdominal pain'},
#  'C0151594': {'blood-streaked diarrhea'},
#  'C0085593': {'chills'},
#  'C1961006': {'recent weight loss'},
#  'C0220870': {'light-headedness', 'lightheadedness'},
#  'C0012833': {'dizziness', 'dizzy'},
#  'C0042023': {'increased urinary frequent', 'urinary frequency'},
#  'C0445115': {'normal saline'},
#  'C0026549': {'morphine'},
#  'C0583980': {'further management'},
#  'C0032285': {'Pneumonia', 'her pneumonia', 'his pneumonia', 'pneumonia'},
#  'C0700777': {'Prilosec'},
#  'C0030920': {'PUD', 'peptic ulcer disease'},
#  'C0034107': {'HR',
#   'Heart rate',
#   'Her pulse',
#   'Her rate',
#   'P',
#   'Pulses',
#   'The heart rate',
#   'a heart rate',
#   'a rate',
#   'heart rate',
#   'illation )',
#   'ng edema and',
#   'p',
#   'pulse',
#   'pulses'},
#  'C0005824': {'120 per minut',
#   'BP',
#   'Blood pressure',
#   'His blood pressure',
#   'The blood pressure',
#   'a blood pressure',
#   'blood pressure',
#   'his blood pressure',
#   'that blood pressure'},
#  'C1443397': {'R',
#   'RR',
#   'a respiratory rate',
#   'respirations',
#   'respiratory rate'},
#  'C1167958': {'Heart sounds were no',
#   'JVD',
#   'Neck veins distended',
#   'jugular venous distention'},
#  'C0577599': {'non-distended', 'nondistended'},
#  'C0234234': {'Tender'},
#  'C0038002': {'an enlarged spleen', 'splenomegaly'},
#  'C0019214': {'hepatosplenomegaly'},
#  'C1287940': {'Deep tendon reflexes',
#   'Her deep tendon reflexes',
#   'The deep tendon reflexes'},
#  'C0423553': {'light touch'},
#  'C0438930': {'Chem-7', 'SMA-7', "The patient 's SMA 7", 'panel 7'},
#  'C0337443': {'Na', 'Sodium', 'a sodium', 'his sodium levels', 'sodium'},
#  'C0202194': {'K', 'Potassium', 'a potassium', 'potassium'},
#  'C0201952': {'Cl', 'chloride'},
#  'C0202059': {'bicarb', 'bicarbonate'},
#  'C0005845': {'BUN', 'Blood urea nitrogen', 'Bun', 'a BUN', 'wa'},
#  'C0201975': {'Cr', 'Creat', 'a creatinine', 'creatinine', 'vated at 2'},
#  'C0337438': {'a glucose', 'a sugar', 'glucose', 'the sugar'},
#  'C0023901': {'Liver function tests',
#   'The liver function tests',
#   'These liver function tests',
#   'liver function tests'},
#  'C0201836': {'ALT', 'an ALT'},
#  'C0201899': {'AST', 'GOT', 'SGOT'},
#  'C0201850': {'Alkaline phosphatase',
#   'Her alkaline phosphatase',
#   'alk phos',
#   'alkaline phosphatase',
#   'an alkaline phosphatase'},
#  'C0201913': {'T. bili', 'Total bilirubin', 'a total bili', 'total bilirubin'},
#  'C0201916': {'D. bili', 'direct bilirubin'},
#  'C0201883': {'amylase'},
#  'C0373670': {'lipase'},
#  'C0555903': {'T. protein', 'Total protein', 'total protein'},
#  'C0201838': {'albumin', 'albumin|levels'},
#  'C0877347': {'globulin'},
#  'C0201925': {'Ca',
#   'Calcium levels',
#   'Her calcium',
#   'calcium',
#   'calcium|levels'},
#  'C0009555': {'CBC',
#   'Complete blood count',
#   'The complete blood count',
#   'complete blood count',
#   'eatinine were within n'},
#  'C0023508': {'The patient &apos;s white count',
#   'The white blood count',
#   'WBC',
#   'White blood cell count',
#   'White blood count',
#   'White count',
#   'a white blood cell',
#   'a white blood cell count',
#   'a white blood count',
#   'a white cell count',
#   'a white count',
#   'his white count',
#   'the patient &apos;s white blood cell count',
#   'the patient &apos;s white blood count',
#   'the white blood cell count',
#   'the white blood count',
#   'white blood cell count',
#   'white blood cells',
#   'white blood count',
#   'white count'},
#  'C0587341': {'hemoglobin'},
#  'C0018935': {'Hct',
#   'Hematocrit',
#   'Her hematocrit',
#   'His hematocrit',
#   'a hematocrit',
#   'hematocrit',
#   'her hematocrit',
#   'his hematocrit'},
#  'C0032181': {'his platelet count',
#   'platelet',
#   'platelet count',
#   'platelets',
#   'the platelets'},
#  'C0011923': {'Imaging studies', 'imaging', 'scans'},
#  'C0412620': {'Abd CT',
#   'Abdominal CT scan',
#   'CT|abdomen',
#   'The CT of the abdomen',
#   'an abdominal CT',
#   'chest X-Ray , and'},
#  'C0000833': {'abscess'},
#  'C0333161': {'pseudocyst'},
#  'C0747635': {'Bilateral pleural effusion', 'bilateral effusions'},
#  'C0203464': {'Abdominal ultrasound'},
#  'C0282074': {'biliary sludge', 'gallbladder sludge'},
#  'C0008350': {'cholelithiasis', 'gallstone'},
#  'C0032227': {'pleural effusion'},
#  'C0202793': {'Chest ( PA and lateral )'},
#  'C0332448': {'infiltrate', 'infiltrates', 'ionfiltrative'},
#  'C0702116': {'consolidation', 'consolidations'},
#  'C0419179': {'NPO'},
#  'C0522792': {'IV fluids', 'intravenous fluids'},
#  'C1304888': {'Pain control', 'pain control'},
#  'C0935966': {'Demerol'},
#  'C0232493': {'epigastric pain',
#   'his epigastric pain',
#   'midepigastric abdominal pain',
#   'the patient &apos;s epigastric pain'},
#  'C0159028': {'his symptoms', 'symptoms', 'these symptoms'},
#  'C0030286': {'a pancreatic complication'},
#  'C0027540': {'necrosis', 'necrotic'},
#  'C0040405': {'A CT',
#   'A computerized tomography scan',
#   'CT',
#   'CT scan',
#   'a CG scan',
#   'a CT scan',
#   'a computerized tomography scan',
#   'the computerized tomography scan'},
#  'C0585008': {'biliary dilatation'},
#  'C0039985': {'A chest X-ray',
#   'A chest x-ray',
#   'Achest x-ray',
#   'CXR',
#   'Chest X-ray',
#   'Chest x-ray',
#   'Chest xray',
#   'His chest X-ray',
#   'His chest x-ray',
#   'The chest X-ray',
#   'The patient &apos;s chest x-ray',
#   'a chest x-ray',
#   'chest X-ray',
#   'chest x-ray',
#   'her chest x-ray',
#   'his chest x-ray',
#   'mmogram wer',
#   'the chest x-ray'},
#  'C0013687': {'effusion'},
#  'C0007554': {'Cefotaxime', 'The cefotaxime', 'cefotaxime'},
#  'C1299622': {'empiric antibiotic treatment'},
#  'C0041618': {'An ultrasound', 'The ultrasound', 'this ultrasound'},
#  'C0008370': {'cholestasis', 'cholestatic'},
#  'C0008311': {'CHOLANGITIS', 'cholangitis'},
#  'C0009450': {'Infectious Disease', 'infection'},
#  'C0086787': {'PERCOCET', 'Percocet', 'wed up b'},
#  'C0301532': {'MVI', 'Multivitamin', 'multivitamins'},
#  'C0423641': {'left flank pain'},
#  'C1444775': {'sharp'},
#  'C0085606': {'urinary|urgency'},
#  'C0004144': {'atelectasis', 'collapsed lung'},
#  'C0728938': {'partially'},
#  'C0262581': {'CURRENT MEDICATIONS : H',
#   'NKDA',
#   'No known drug allergies',
#   'denies any drug allergies',
#   'no known drug allergies',
#   'no known drug allergy'},
#  'C0225704': {'Bibasilar', 'bibasilar', 'bilateral basilar', 'both bases'},
#  'C0030247': {'palpation'},
#  'C0230180': {'LLQ', 'left lower abdomen', 'left lower quadrant'},
#  'C0205091': {'left'},
#  'C0524467': {'costovertebral angle'},
#  'C0030274': {'pancreas'},
#  'C0205402': {'Prominent', 'noted', 'prominent'},
#  'C0700321': {'small'},
#  'C0264499': {'compression atelectasis'},
#  'C0332281': {'associated', 'related'},
#  'C0227582': {'body|of the pancreas'},
#  'C0438653': {'Portable', 'Portable|x-ray'},
#  'C0817096': {'chest'},
#  'C2242979': {'Cultures', 'culture', 'cultured', 'cultures'},
#  'C0034642': {'Crackles', 'Rales', 'crackles', 'rales'},
#  'C0332217': {'continued', 'persistent'},
#  'C0521114': {'n-sustaine', 'occasional', 'occasionally'},
#  'C0728755': {'Dilaudid'},
#  'C2317349': {'IV', 'intravenous'},
#  'C0227546': {'gallbladder neck'},
#  'C0577559': {'a mass', 'lump', 'mass', 'the mass'},
#  'C0849584': {'Followup', 'follow up', 'follow-up'},
#  'C0242970': {'diet|low fat'},
#  'C0205208': {'solids'},
#  'C0030305': {'pancreatitis'},
#  'C0444956': {'high dose'},
#  'C1960986': {'pain|radiation to the lower abdomen'},
#  'C1960997': {'pain|radiation to|upper quadrant'},
#  'C0278145': {'stabbing|pain', 'the pain|knife-like'},
#  'C0200949': {'Blood cultures',
#   'Blood|cultures',
#   'blood culture',
#   'blood cultures'},
#  'C0430404': {'aurine culture',
#   'the patient &apos;s urine culture',
#   'urine cultures'},
#  'C0267099': {'Pill esophagitis', 'pill esophagitis'},
#  'C0455855': {'Right ventricular hypokinesis',
#   'her right ventricular hypokinesis',
#   'right ventricular|septal hypokinesis'},
#  'C1828348': {'Dobutamine stress test',
#   'a dobutamine stress test',
#   'dobutamine stress test'},
#  'C0013516': {'96 . HOSPITAL COU',
#   'An echocardiogram',
#   'Cardiac echocardiogram',
#   'ECHO',
#   'Echo',
#   'Echocardiogram',
#   'The echocardiogram',
#   'This echo',
#   'cardiac echo',
#   'cardiac ultrasound',
#   'echo',
#   'echocardiogram',
#   'etely normal left',
#   'the echocardiogram'},
#  'C0079304': {'EGD',
#   'Esophagogastroduodenoscopy',
#   'The EGD',
#   'an EGD',
#   'an esophagogastroduodenoscopy',
#   'an upper endoscopy',
#   'her EGD'},
#  'C1827584': {'PICC placement'},
#  'C0020538': {'HTN',
#   'HYPERTENSION',
#   'Hypertension',
#   'her hypertension',
#   'hypertension',
#   'l carcinoma',
#   'of subtotal',
#   'r ; subtotal'},
#  'C0024117': {'CHRONIC OBSTRUCTIVE PULMONARY DISEASE',
#   'COPD',
#   'Chronic obstructive pulmonary disease',
#   'chronic obstructive lung disease',
#   'chronic obstructive pulmonary disease',
#   'e pulmonary disease , pulmonary hyper'},
#  'C0011581': {'depression'},
#  'C0018802': {'CHF',
#   'CONGESTIVE HEART FAILURE',
#   'Congestive heart failure',
#   'ailure , chronic obstruc',
#   'congestive heart failure'},
#  'C0541828': {'left-sided chest pain'},
#  'C0013404': {'CAL HISTORY : Inclu',
#   'SOB',
#   'Shortness of Breath',
#   'Shortness of breath',
#   'dyspnea',
#   'short of breath',
#   'shortness of breath',
#   'sob'},
#  'C0010200': {'cough', 'coughing'},
#  'C3466369': {'sl ntg',
#   'sublingual nitroglycerin',
#   'sublingual nitroglycerins'},
#  'C0004057': {'ACETYLSALICYLIC ACID',
#   'Aspirin',
#   'His aspirin',
#   'The aspirin',
#   'aspirin',
#   'his aspirin'},
#  'C0700776': {'LOPRESSOR', 'Lopressor', 'lopressor'},
#  'C0021641': {'Insulin', 'Regular insulin', 'insulin Regular'},
#  'C0020456': {'hyperglycemia'},
#  'C1623258': {'An EKG',
#   'An electrocardiogram',
#   'ECG',
#   'EKG',
#   'Electrocardiogram',
#   'Her EKG',
#   'His ECG',
#   'The electrocardiogram',
#   'an electrocardiogram',
#   'electrocardiogram',
#   'prior to discharge ,'},
#  'C0011854': {'INSULIN DEPENDENT DIABETES MELLITUS',
#   'Insulin dependent diabetes mellitus',
#   'Insulin-dependent diabetes mellitus',
#   'insulin dependent diabetes mellitus'},
#  'C0004604': {'back pain'},
#  'C2607914': {'allergic rhinitis'},
#  'C0028754': {'Obese', 'Obesity', 'obese', 'obesity'},
#  'C0020473': {'hyperlipidemia'},
#  'C0009214': {'Codeine'},
#  'C0591130': {'Atrovent'},
#  'C0286677': {'Flonase'},
#  'C0034417': {'Quinine'},
#  'C0719198': {'Celebrex'},
#  'C0701017': {'Compazine'},
#  'C0069805': {'Oxybutynin'},
#  'C0002600': {'Amitriptyline'},
#  'C0162723': {'Zyrtec'},
#  'C0162373': {'Prozac'},
#  'C0040805': {'Trazadone', 'Trazodone', 'trazadone', 'trazodone'},
#  'C3538423': {'Humulin'},
#  'C0001927': {'Albuterol', 'albuterol'},
#  'C0699992': {'.i.d.', 'GIES', 'Lasix', 'ceril'},
#  'C0360583': {'Triamcinolone cream'},
#  'C1251997': {'Miconazole cream'},
#  'C0720466': {'Flovent'},
#  'C0065374': {'LISINOPRIL', 'Lisinopril', 'lisinopril'},
#  'C0032825': {'K-Dur',
#   'KCL',
#   'KCl',
#   'Kay Ciel',
#   'Kay-Ceil',
#   'POTASSIUM CHLORIDE',
#   'Potassium chloride',
#   'potassium chloride'},
#  'C0876139': {'Protonix'},
#  'C0593906': {'Lipitor'},
#  'C0025605': {'Methadone'},
#  'C1384666': {'hard of hearing', 'poor hearing'},
#  'C0004339': {'auscultation', 'demonstrate'},
#  'C1706488': {'DP', 'dorsalis pedis pulses'},
#  'C0085610': {'sinus brady', 'sinus bradycardia'},
#  'C0232326': {'ST segment changes',
#   'ST-T wave changes',
#   'STT wave abnormalities',
#   'nonspecifi|te blood coun'},
#  'C0027051': {'MI',
#   'MYOCARDIAL INFARCTION',
#   'a myocardial infarction',
#   'formyocardial infarction',
#   'mi',
#   'myocardial infarction'},
#  'C1271630': {'cardiac markers'},
#  'C1998088': {'the stress portion'},
#  'C0020649': {'hypotension', 'hypotensive'},
#  'C0430462': {'His TTE',
#   'a TTE',
#   'a cardiac echo ( transthoracic echocardiogram )',
#   'transthoracic echocardiogram'},
#  'C0428772': {'LV ejection fraction', 'left ventricular ejection fraction'},
#  'C0456181': {'RVSP'},
#  'C0520541': {'a hypotensive episode', 'hypotensive'},
#  'C2317227': {'fluid bolus', 'fluid boluses'},
#  'C0948268': {'hemodynamic instability', 'her tenuous hemodynamic status'},
#  'C1384495': {'This stress test'},
#  'C0022116': {'ische', 'ischemia', 'ischemic'},
#  'C0232174': {'EF',
#   'EJECTION FRACTION',
#   'Ejection fraction',
#   'an EF',
#   'an ejection fraction',
#   'ejection fraction',
#   'than 50% . She did'},
#  'C0012963': {'dobutamine'},
#  'C0574066': {'increased dyspnea',
#   'increased shortness of breath',
#   'increasing shortness of breath',
#   'progressive shortness of breath'},
#  'C0282386': {'Her levofloxacin',
#   'LEVOFLOXACIN',
#   'Levo',
#   'Levofloxacin',
#   'a levofloxacin',
#   'levofloxacin'},
#  'C0042029': {'URINARY TRACT INFECTION',
#   'UTI',
#   'Urinary tract infection',
#   'urinary tract infection'},
#  'C0239574': {'low grade temperatures', 'low-grade fevers'},
#  'C0007561': {'ceftriaxone'},
#  'C0052796': {'azithromycin'},
#  'C0018155': {'gram-positive cocci'},
#  'C0042313': {'Vancomycin', 'her vancomycin', 'vancomycin'},
#  'C0004611': {'These bacteria', 'bacteria'},
#  'C1265292': {'MRSA'},
#  'C0179740': {'PICC line', 'a PICC line'},
#  'C0994475': {'pills'},
#  'C1142536': {'MRSA pneumonia'},
#  'C0878881': {'nasal cannula'},
#  'C0020542': {'. Because of her deter',
#   'Pulmonary hypertension',
#   'She was referred for',
#   'pulmonary hypertension',
#   'sion . PRINCIPAL PROCE'},
#  'C0202823': {'A chest CT',
#   'Chest CT',
#   'chest CT',
#   'chest computerized tomography scan'},
#  'C0043393': {'yeast'},
#  'C0723950': {'Tums'},
#  'C0354688': {'ALBUTEROL INHALER',
#   'Albuterol inhaler',
#   'Albuterol inhalers',
#   'albuterol inhaler'},
#  'C0360575': {'Flovent inhaler'},
#  'C0591395': {'Ditropan'},
#  'C0021658': {'Insulin NPH', 'NPH', 'NPH insulin'},
#  'C1247198': {'Nystatin Mouthwash'},
#  'C0939400': {'Nexium'},
#  'C0205392': {'The', 'some'},
#  'C0205156': {'ation', 'olizatio', 'previous', 'prior'},
#  'C0439654': {'faint'},
#  'C0043144': {'Wheezing', 'wheezes', 'wheezing'},
#  'C1720310': {'PT'},
#  'C0205219': {'Diffuse', 'ch were', 'diffuse', 'diffusely'},
#  'C0232172': {'hypokinesis', 'hypokinetic'},
#  'C0205314': {'new'},
#  'C1261074': {'right upper lobe'},
#  'C0151970': {'esophageal ulcers'},
#  'C0235239': {'fluttering|chest'},
#  'C0549178': {'continued', 'continuous', 'persistent', 'persistently'},
#  'C1287678': {'lung volumes'},
#  'C0205251': {'low'},
#  'C0205341': {'Repeat', 'another', 'repeat', 'repeated'},
#  'C3164773': {'septal thinning'},
#  'C0205094': {'anterior'},
#  'C0042036': {'urine'},
#  'C1275772': {'legionella antigen'},
#  'C1533734': {'administration'},
#  'C0178602': {'dose', 'doses'},
#  'C0686904': {'requirement', 'requirements'},
#  'C0030054': {'02', 'oxygen', 'the oxygen'},
#  'C1277298': {'erythematous rash'},
#  'C0360376': {'Miconazole Cream'},
#  'C0028066': {'Nifedipine'},
#  'C1997551': {'LV|wall motion abnormality'},
#  'C0032290': {'ASPIRATION PNEUMONIA',
#   'The aspiration pneumonia',
#   'aspiration pneumonia'},
#  'C0239886': {'frontal headaches', 'headache across the forehead'},
#  'C2830004': {'somnolent'},
#  'C0006318': {'bruit', 'bruits'},
#  'C0238844': {'Decreased breath sounds',
#   'decreased breath sounds',
#   'poor air entry'},
#  'C0278249': {'without any speech'},
#  'C0034944': {'Dolls eye'},
#  'C0010031': {'Corneals'},
#  'C1287907': {'Gag'},
#  'C0200116': {". Patient 's gait",
#   'Sensory examination',
#   'sensory examination',
#   'sensory testing'},
#  'C0596002': {'Reflexes'},
#  'C1282911': {'upgoing'},
#  'C0344395': {'bilirubin', 'bilirubins'},
#  'C0201973': {'CK', 'CPK', 'a creatine kinase', 'creatine kinases'},
#  'C0040130': {'Thyroid function tests'},
#  'C0920210': {'Trop-I', 'Troponin I'},
#  'C0523826': {'phosphate', 'phosphate levels'},
#  'C0373675': {'Magnesium', 'magnesium'},
#  'C0033707': {'Her PT',
#   'PT',
#   'PTs',
#   'Prothrombin time',
#   'The patient &apos;s pro time',
#   'a PT',
#   'a prothrombin time',
#   'her prothrombin time',
#   'his PT',
#   'pro time checks',
#   'prothrombin time',
#   'prothrombin times',
#   'the patient &apos;s prothrombin time',
#   'the prothrombin time'},
#  'C0030605': {'PTT', 'partial thromboplastin time'},
#  'C0085614': {'first degree atrioventricular block'},
#  'C1287083': {'biphasic T-waves'},
#  'C0202691': {'A computerized tomography scan of the head',
#   'A head CT',
#   'A head CT scan',
#   'CAT scan of the head',
#   'Head CT',
#   'Head CT scan',
#   'Head computerized tomography scan',
#   'The head CT scan',
#   'a CT scan of the head',
#   'head ct',
#   'ich pat'},
#  'C0576481': {'midline shift'},
#  'C0019134': {'Heparin', 'heparin', 'her heparin', 'lating'},
#  'C0436121': {'Lung exam', 'Lung examination', 'The lung examination'},
#  'C0005800': {'A blood gas', 'Blood gases', 'blood gas', 'blood gases'},
#  'C0202165': {'PH', 'a pH'},
#  'C0428168': {'P02', 'pO2'},
#  'C0428189': {'PC02', 'a pCO2', 'pCO2'},
#  'C0039239': {'Sinus tachycardia', 'sinus tachycardia'},
#  'C0029053': {'a high density'},
#  'C0585630': {'the right cerebellar infarction'},
#  'C0019080': {'any bleeding',
#   'bleed',
#   'bleed ing',
#   'bleeding',
#   'blood',
#   'blood loss',
#   'fresh blood',
#   'hemorrhage'},
#  'C0024485': {'An MRI',
#   'MRI',
#   'MRI scan',
#   'The MRI',
#   'the magnetic resonance imaging study'},
#  'C1636167': {'MRA of the head', 'MRA of the intracranial'},
#  'C0038454': {'CEREBROVASCULAR ACCIDENT',
#   'CVA',
#   'a stroke',
#   'his stroke',
#   'stroke',
#   'the stroke'},
#  'C0006114': {'cerebellar swelling'},
#  'C0231187': {'decompensation'},
#  'C0204700': {'fluid restriction'},
#  'C1272452': {'blood pressure management'},
#  'C2937358': {'intercerebral hemorrhage'},
#  'C0025872': {'METRONIDAZOLE', 'Metronidazole'},
#  'C0028785': {'OCCIPITAL'},
#  'C0205231': {'EXTENSIVE', 'extensive'},
#  'C0393956': {'POSTERIOR CIRCULATION INFARCTION'},
#  'C0278061': {'MENTAL STATUS CHANGE',
#   'MENTAL STATUS CHANGES',
#   'change in mental status'},
#  'C1276802': {'acute', 'acutely'},
#  'C0205345': {'relatively'},
#  'C0237284': {'unresponsive'},
#  'C0232249': {'1 out of 6|murmur', 'I/VI|murmur', 'one out of six|murmur'},
#  'C0232258': {'holosystolic murmur'},
#  'C0205267': {'intermittent', 'intermittently'},
#  'C0424536': {'alert'},
#  'C0034121': {'pupillary'},
#  'C1457869': {'defect'},
#  'C0439765': {'right gaze'},
#  'C0026649': {'movement'},
#  'C0547040': {'minimal'},
#  'C0450414': {'left side'},
#  'C0205184': {'biphasic'},
#  'C0443172': {'change', 'changes', 'edema'},
#  'C1261077': {'left lower lobe'},
#  'C0455714': {'OCCIPITAL , CEREBRAL INFARCTION',
#   'occipital , cerebral infarction',
#   'occipital cerebral infarction',
#   'occipital infarct',
#   'occipital lobe infarction'},
#  'C0549177': {'large'},
#  'C0152283': {'temporal horn'},
#  'C1280500': {'affect', 'effect'},
#  'C0429673': {'respiratory status'},
#  'C1287665': {'breath sounds'},
#  'C0205194': {'coarse'},
#  'C0332273': {'throughout'},
#  'C1960093': {'non-rebreather mask', 'nonrebreather'},
#  'C1305553': {'100%'},
#  'C3536610': {'posterior cerebral artery infarction'},
#  'C0205095': {'posterior'},
#  'C0225804': {'circulation'},
#  'C0236073': {'infarct of the cerebellar hemispheres'},
#  'C0238767': {'B', 'b / l', 'bilateral', 'bilaterally'},
#  'C0429856': {'flow'},
#  'C0392756': {'reduced'},
#  'C0004811': {'basilar arteries'},
#  'C0007276': {'internal carotid arteries'},
#  'C0175566': {'patency'},
#  'C0439806': {'gross'},
#  'C1956346': {'CAD',
#   'CORONARY ARTERY DISEASE',
#   'Coronary artery disease',
#   'coronary artery disease',
#   'his coronary artery disease'},
#  'C0010055': {'CABG',
#   'a coronary artery bypass graft',
#   'coronary artery bypass graft'},
#  'C0543467': {'His operation',
#   'a surgical procedure',
#   'any surgical treatment',
#   'e was t',
#   'her surgery',
#   'his surgical procedure',
#   'operations',
#   'surgery',
#   'surgical',
#   'surgical intervention',
#   'surgical procedures',
#   'the operation',
#   'the surgery',
#   'this operation'},
#  'C0189842': {'a pacer implantation', 'pacer placement'},
#  'C0037052': {'sick sinus syndrome'},
#  'C0002962': {'angina', 'anginal', 'anginal pain'},
#  'C0340320': {'anterior myocardial infarction',
#   'prior anterior myocardial infarction'},
#  'C0018795': {', which confirmed sever',
#   'Cardiac catheterization',
#   'a cardiac catheterization',
#   'cardiac catheterization',
#   'this cardiac catheterization'},
#  'C0729538': {'henous vein snake graft', 'saphenous vein graft'},
#  'C0001168': {'100% occluded', 'totally occluded'},
#  'C0006938': {'Capoten', 'Captopril', 'captopril', 'his Captopril'},
#  'C0699988': {'Lanoxin'},
#  'C0700940': {'Cardizem'},
#  'C0591573': {'Glucophage'},
#  'C0595112': {'Amaryl'},
#  'C0150404': {'Her vital signs',
#   'The vital signs',
#   'VS',
#   'Vital signs',
#   'her vital signs',
#   'the vital signs',
#   'vital signs'},
#  'C0205271': {'irregular'},
#  'C0577801': {'Rhythm'},
#  'C0009346': {'Balloon'},
#  'C0128513': {'His Melranon'},
#  'C0003015': {'ACE inhibitors', 'her ACE inhibitor', 'his ACE inhibitor'},
#  'C0002598': {'Amiodarone',
#   'cations .',
#   'rangements',
#   'showed no',
#   'ys . The p'},
#  'C0019573': {'Hirudin'},
#  'C0149871': {'DVT', 'deep venous thrombosis'},
#  'C3539909': {'Allergies', 'Her allergies', 'allergic'},
#  'C0699129': {'Coumadin',
#   'The patient &apos;s Coumadin',
#   'ation ca',
#   'coumadin',
#   'd to hav',
#   'e made t',
#   'his coumadin',
#   'mot DD :',
#   'mpt at D',
#   'qD , Las'},
#  'C0150457': {'Anticoagulation',
#   'Coumadinization',
#   'anticoagulation therapy',
#   'as ultimately disch'},
#  'C0012265': {', 40 ,', 'Dig', 'Digoxin', 'digoxin', 'mg eve'},
#  'C0225873': {'anterior septal'},
#  'C0205329': {'progressive', 'progressively', 're and an e'},
#  'C0162577': {'angioplasty'},
#  'C0439064': {'mulitple', 'multiple'},
#  'C0522776': {'Stent placement', 'stent placement', 'stents'},
#  'C0035110': {'reoperative'},
#  'C0340285': {'a three vessel coronary artery disease',
#   'triple vessel coronary artery disease'},
#  'C1261316': {'RCA', 'right coronary artery'},
#  'C0012634': {'diseased'},
#  'C0226032': {'LAD'},
#  'C0701228': {'Glucotrol'},
#  'C0430458': {'exercise treadmill test'},
#  'C0396777': {'coronary artery bypass graft times three',
#   'coronary artery bypass grafting x 3'},
#  'C0205107': {'proximal'},
#  'C0348047': {'graft'},
#  'C0442181': {'subaortic'},
#  'C0014563': {'Epinephrine', 'epinephrine'},
#  'C0460104': {'drip'},
#  'C1319556': {'heparin induced thrombocytopenia'},
#  'C0302350': {'therapeutic'},
#  'C0524434': {'OM1'},
#  'C0001175': {'AIDS'},
#  'C0007559': {'Ceftazidime', 'ceftazidime'},
#  'C0004521': {'Aztrenam'},
#  'C1299471': {'MAI'},
#  'C0006836': {'Candidal', 'candida', 'candida species', 'candidal'},
#  'C0155860': {'pseudomonal pneumonia', 'pseudomonas pneumonia'},
#  'C0005834': {'blood drawing', 'his blood drawn'},
#  'C0812149': {'IV medications'},
#  'C0234233': {'sore', 'tender', 'tenderness'},
#  'C0041834': {'erythema'},
#  'C0235218': {'warmth'},
#  'C0015388': {'exudate', 'exudates'},
#  'C0010980': {'Dapsone'},
#  'C0701042': {'Cipro'},
#  'C0001367': {'Acyclovir'},
#  'C0025175': {'Megastrol'},
#  'C0210630': {'G-CSF', 'his G-CSF'},
#  'C0018021': {'goiter', 'thyromegaly'},
#  'C0436125': {'Cardiovascular exam', 'Cardiovascular examination'},
#  'C0202113': {'LDH', 'his LDH'},
#  'C0162401': {'Leukocyte differential count',
#   'The differential',
#   'a differential',
#   'differential'},
#  'C0042014': {'A urinalysis',
#   'The patient &apos;s urinalysis',
#   'Urinalysis',
#   'Urine analysis'},
#  'C0427916': {'Sputum gram stain'},
#  'C0027950': {'polys'},
#  'C1271628': {'AFB stain'},
#  'C0085795': {'Amphotericine', 'the Amphotericine'},
#  'C0740299': {'positive blood culture', 'positive blood cultures'},
#  'C0003232': {'The antibiotic',
#   'The patient &apos;s antibiotics',
#   'These antibiotics',
#   'antibiotic',
#   'antibiotics',
#   'his antibiotics',
#   'the antibiotics'},
#  'C0014806': {'Erythro', 'Erythromycin'},
#  'C0591635': {'Imodium'},
#  'C0028741': {'Nystatin'},
#  'C0029997': {'Serax'},
#  'C1268858': {'magnesium replacement'},
#  'C2945760': {'ad a part', 'recurrent'},
#  'C0033817': {'pseudomonas infections'},
#  'C0221423': {'illnesses'},
#  'C0205420': {'Concurrent'},
#  'C1290922': {'Baseline', 'baseline'},
#  'C0230347': {'left arm'},
#  'C0398232': {'graft'},
#  'C1272748': {'CATIONS O', 'resolving'},
#  'C0225740': {'lingular'},
#  'C4281590': {'right mid lung'},
#  'C1275732': {'a port', 'passport'},
#  'C0457453': {'A RHALTKA',
#   'Admission',
#   'admission',
#   'n , digoxin',
#   'on admission'},
#  'C0005841': {'blood transfusions', 'transfused blood'},
#  'C0201992': {'Electrolytes',
#   'His electrolyte panel',
#   'al limits .',
#   'electrolytes',
#   'lytes'},
#  'C0304475': {'potassium|replacement'},
#  'C1271714': {'polys'},
#  'C0200634': {'bands'},
#  'C0200635': {'lymphocytes', 'lymphs'},
#  'C0200637': {'monocytes', 'monos'},
#  'C2945843': {'site', 'site of'},
#  'C0580836': {'old'},
#  'C3714625': {'NEUROPATHIC PAIN', 'neuropathic pain'},
#  'C0406844': {'Post thoracotomy syndrome',
#   'post thoracotomy syndrome',
#   'postthoracotomy syndrome'},
#  'C0039991': {'her thoracotomy incision', 'thoracotomy'},
#  'C0162872': {'a thoracic aortic aneurysm'},
#  'C0449681': {'the incision site'},
#  'C0483514': {'Vicodin'},
#  'C0087119': {'Elavil'},
#  'C0678176': {'Neurontin'},
#  'C0459914': {'conservative therapy', 'the conservative therapy'},
#  'C0020676': {'Hypothyroidism', 'hypothyroid', 'hypothyroidism'},
#  'C0030486': {'Paraplegia', 'a paraplegic from T4 down', 'paraplegia'},
#  'C0521233': {'her thoracic aortic aneurysm repair',
#   'thoracic aortic aneurysm repair'},
#  'C0558159': {'Sacral decubitus ulcer',
#   'sacral decubitus',
#   'the sacral decubitus ulcer'},
#  'C1960973': {'HOME O2', 'Home oxygen', 'home oxygen'},
#  'C0043143': {'a wheelchair'},
#  'C2919541': {'neb', 'nebulizer', 'nebulizers'},
#  'C0162712': {'Norvasc'},
#  'C0009316': {'Colistin'},
#  'C0558009': {'Pressure , dermal ulcer care'},
#  'C0085671': {'adressing change', 'dressing change', 'dressing changes'},
#  'C0003968': {'ASCORBIC ACID', 'VITAMIN C', 'Vitamin C'},
#  'C0006681': {'Calcium carbonate'},
#  'C0178638': {'Folate'},
#  'C0728762': {'Synthroid'},
#  'C0078794': {'Zinc sulfate'},
#  'C0024476': {'Milk of Magnesia'},
#  'C0009806': {'Constipation', 'constipated', 'constipation'},
#  'C0220892': {'PCN', 'PENICILLIN', 'penicillin'},
#  'C0011394': {'dentures'},
#  'C0456653': {'Epidural site'},
#  'C0013119': {'a dressing'},
#  'C0039082': {'the syndrome'},
#  'C3878277': {'The spinal cord stimulator',
#   'a spinal cord stimulator',
#   'spinal cord stimulator'},
#  'C0184661': {'The procedure',
#   'and was taken',
#   'any procedures',
#   'his procedure',
#   'procedure',
#   'procedures',
#   'the procedure'},
#  'C0578060': {'her pain pattern'},
#  'C0179751': {'Her epidural catheter',
#   'The epidural catheter',
#   'an epidural catheter'},
#  'C0002913': {'The epidural', 'epidural'},
#  'C0085590': {'catheter', 'his catheter', 'the catheter'},
#  'C0456214': {'epidural pump placement', 'placement of epidural pump'},
#  'C0876973': {'lung infections'},
#  'C0225732': {'left base'},
#  'C0425543': {'coarse rales'},
#  'C0008035': {'chest wall pain'},
#  'C0455270': {'sharp pain'},
#  'C0785724': {'Fentanyl patch 25 mcg an hour'},
#  'C1562252': {'Left hemidiaphragmatic'},
#  'C0522224': {'paralysis'},
#  'C0037633': {'solution'},
#  'C0717367': {'Hydrocodone|with Tylenol'},
#  'C0085620': {'Flaccid paralysis'},
#  'C0230420': {'AL C',
#   'BLE',
#   'bilateral lower extremities',
#   'legs',
#   'lower extremities'},
#  'C0026858': {'musculoskeletal|pain'},
#  'C0574032': {'infusion'},
#  'C0191651': {'excision and closure flap of|ischial decubitusin',
#   'excision and closure of|ischial sacral decubitus'},
#  'C0185003': {'closure'},
#  'C0182537': {'pump'},
#  'C0560563': {'fluoroscope to guide'},
#  'C0347944': {'PELVIC MASS',
#   'Pelvic mass',
#   'a pelvic mass',
#   'pelvic mass',
#   'the pelvic mass'},
#  'C0474186': {'ERT'},
#  'C0728940': {'excision', 'resection'},
#  'C0701459': {'Lupron'},
#  'C3497606': {'Vicodin ES'},
#  'C0724054': {'Ultram'},
#  'C0011168': {'an inability to tolerate p.o. intake',
#   'difficulties with swallowing',
#   'dysphagia'},
#  'C0227791': {'vaginal discharge'},
#  'C0559692': {'intravenous fluid'},
#  'C0032821': {'Potassium', 'ic acid r', 'potassium'},
#  'C0008947': {'clindamycin'},
#  'C0699187': {'Valium'},
#  'C0013136': {'droperidol'},
#  'C0003864': {'arthritis'},
#  'C0002871': {'ANEMIA', 'anemia', 'din wa'},
#  'C0004096': {'asthma'},
#  'C0542407': {'A TAH-BSO',
#   'total abdominal hysterectomy-bilateral salpingo-oophorectomy'},
#  'C0085704': {'an exploratory laparotomy', 'exploratory laparotomy'},
#  'C0042523': {'Verapamil'},
#  'C0020261': {'. b.i.d. , Zantac 1',
#   'HCTZ',
#   'HYDROCHLOROTHIAZIDE',
#   'd. and Decadron 25',
#   'hydrochlorothiazide'},
#  'C0210355': {'Arthrotec'},
#  'C0965130': {'Advair'},
#  'C0025231': {'Tofranil'},
#  'C0487782': {'AMBIEN', 'Ambien'},
#  'C0060282': {'Ferrous sulfate', 'iron sulfate'},
#  'C0236024': {'throat edema'},
#  'C0699678': {'FLAGYL', 'Flagyl', 'flagyl'},
#  'C0016169': {'a sinus tract', 'fistula', 'sinus tract'},
#  'C0009063': {'C. perfringens'},
#  'C0034065': {'PE'},
#  'C0193063': {'rectosigmoid resection'},
#  'C0192601': {'SBR'},
#  'C0015252': {'removal'},
#  'C0042258': {'a vaginal tumor'},
#  'C0198614': {'an omentectomy', 'omentectomy'},
#  'C0192579': {'an enterotomy'},
#  'C1301707': {'a PCEA'},
#  'C0003467': {'Anxiety', 'anxiety', 'anxious', 'ion or'},
#  'C0020934': {'imipramine'},
#  'C0014025': {'Enalapril', 'enalapril'},
#  'C0020223': {'Hydralazine', 'hydralazine'},
#  'C0022860': {'labetalol'},
#  'C0025859': {'Metoprolol', 'metoprolol'},
#  'C0871470': {'SBP', 'an SBP', 'systolic', 'the systolic blood pressure'},
#  'C0051696': {'amlodipine'},
#  'C0199447': {'nebulizer treatment', 'nebulizer treatments'},
#  'C0004936': {'psychiatric issues'},
#  'C0039231': {'tachycardia', 'tachycardic'},
#  'C0032320': {'free air', 'free air under the diaphragm'},
#  'C0192589': {'a small bowel enterotomy'},
#  'C0456904': {'Intraoperatively'},
#  'C0035229': {'respiratory insufficiency', 'respiratory insuffiencey'},
#  'C0021925': {'intubated', 'intubation'},
#  'C0085678': {'An nasogastric tube',
#   'His nasogastric tube',
#   'The NG tube',
#   'The nasogastric tube',
#   'a nasogastric',
#   'a nasogastric tube',
#   'an NG tube',
#   'nasogastric tube',
#   'the NG tube',
#   'the nasogastric tube'},
#  'C2184084': {'clear liquid diet', 'clear liquids', 'clear sips', 'clears'},
#  'C0030548': {'TPN'},
#  'C0242295': {'nutritional supplementation'},
#  'C0489460': {'calorie counts'},
#  'C1278795': {'removal of the ureteral stents'},
#  'C0013090': {'doxycycline'},
#  'C0016277': {'Fluconazole', 'fluconazole'},
#  'C3874363': {'JP drain'},
#  'C0353681': {'sub .q. heparin'},
#  'C0557977': {'insulin sliding scale', 'sliding scale'},
#  'C0457575': {'Fingerstick', 'fingersticks'},
#  'C0238551': {'left lower quadrant pain'},
#  'C0205394': {'Other', 'other'},
#  'C0012826': {'lysis of adhesions'},
#  'C0194341': {'ureterolysis'},
#  'C0078944': {'PCA', 'a PCA'},
#  'C0205265': {'d , large', 'initial'},
#  'C0175673': {'emergent'},
#  'C0549099': {'peroration'},
#  'C1299597': {'empiric', 'empiric treatment'},
#  'C0205436': {'second'},
#  'C0087111': {'his treatment',
#   'taxis . S',
#   'the best treatment',
#   'therapy',
#   'treatment',
#   'tx'},
#  'C3874410': {'left lower quadrant mass'},
#  'C1276428': {'cystic'},
#  'C1276437': {'solid'},
#  'C0449432': {'components'},
#  'C0239783': {'pain in the groin'},
#  'C0521377': {'rectosigmoid'},
#  'C0027651': {'AL / SURG',
#   'a &quot; tumor &quot;',
#   'his tumor',
#   'neoplasm',
#   'the tumor',
#   'tumor'},
#  'C0150207': {'PE protocol'},
#  'C3853134': {'poorly controlled'},
#  'C0005388': {'bilious fluid'},
#  'C0031153': {'peritoneum'},
#  'C0445247': {'same', 'similar'},
#  'C0332189': {'episode', 'the episodes'},
#  'C0374711': {'repair', 'surgical repair'},
#  'C0012155': {'diet'},
#  'C0730463': {'advancement'},
#  'C3698358': {'stoma output'},
#  'C0445377': {'IJ line'},
#  'C4039428': {'upper extremity Dopplers'},
#  'C0745497': {'IJ clot'},
#  'C0445119': {'no growth'},
#  'C0026269': {'. ASSOCIATED DI',
#   'MITRAL STENOSIS',
#   'Mitral stenosis',
#   'STENOSIS . Uns',
#   'ondary tricuspi',
#   'vere pulmonary'},
#  'C0040961': {'TR',
#   'Tricuspid regurgitation',
#   'ation due to pulmonary hypert',
#   'iency , atrial fibrilla',
#   'tricuspid insufficiency',
#   'tricuspid regurgitation'},
#  'C0004238': {'AF',
#   'ASSOCIATED DIAGNOS',
#   'ATRIAL FIBRILLATION',
#   'Atrial fibrillation',
#   'FIBRILLATION . Uns',
#   'afib',
#   'atrial fibrillation',
#   'conds . There were',
#   'extubated on the t',
#   'improved over time',
#   'n , congestive hear',
#   'noted to be anxiou'},
#  'C0026268': {'ment and tricuspid valve',
#   'mitral valve replacement',
#   'zing a 27 mm . St. Jude pr'},
#  'C0396899': {'ing anuloplasty . She weaned f',
#   'nstruction . HISTORY OF PRESEN'},
#  'C0035436': {'past , and has', 'rheumatic fever'},
#  'C0694539': {'ation . She has had progres', 'chronic atrial fibrillation'},
#  'C1261322': {'Assessment', 'eval', 'evaluation', 'ted worsening'},
#  'C0190065': {'CAL HISTORY i'},
#  'C0746102': {'o smoking . She had'},
#  'C0030600': {'2 . Her MEDICATIONS O',
#   'a partial gastrectomy',
#   'partial gastrectomy'},
#  'C0577863': {'h prominent V-waves , an'},
#  'C1532767': {'ic and diastolic'},
#  'C0577835': {'Peripheral pulses',
#   'Pulses',
#   'ct , and there wa',
#   'her peripheral pulses'},
#  'C0182440': {'# 19 St. Jude valve',
#   'a St. Jude &apos;s mechanical valve',
#   'valve reconstructi'},
#  'C0677555': {'cardiopulmonary'},
#  'C0007202': {'odynamics . She initia'},
#  'C0683369': {'Care Uni', 'confused', 'confusion'},
#  'C0338659': {'continued to improve , with mobi'},
#  'C0428978': {'rillation , but this gradua', 'slow ventricular response'},
#  'C1879316': {'His transfusions',
#   'a transfusion',
#   'd her antico',
#   'the transfusions',
#   'transfusing',
#   'transfusion',
#   'transfusions',
#   'transfusionsm'},
#  'C0302583': {'din', 'iron', 'iron products'},
#  'C0556110': {'ND C. ALL , M.D. TR :'},
#  'C0018801': {'aluation demo', 'heart failure'},
#  'C0175668': {'e regurgi'},
#  'C0472529': {'for treatment of recurrent'},
#  'C0014591': {'Epistaxis',
#   'al gastre',
#   'bleeding from the|nose',
#   'epistaxis',
#   'nasal hemorrhage'},
#  'C0004906': {'EXAMINAT', 'Vanceril'},
#  'C0021461': {'ON demo'},
#  'C1301772': {'ated mild', 'relevant'},
#  'C0232257': {'. Perip|re all', 'systolic murmur'},
#  'C0232262': {'diastolic murmur', 'pulses were all'},
#  'C0277919': {'gs , with som'},
#  'C0085631': {'agitated', 'agitation', 'an Inten', 'her agitation'},
#  'C0750482': {'slightly', 'y due to'},
#  'C3871203': {'otassium , 2'},
#  'C0281936': {'PARTIAL SMALL BOWEL OBSTRUCTION',
#   'partial small bowel obstruction'},
#  'C1282272': {'a low anterior resection'},
#  'C0034897': {'a recurrence'},
#  'C2939419': {'any metastatic process', 'metastasis', 'metastatic disease'},
#  'C0426737': {'decreased output from the ostomy'},
#  'C0700017': {'Naprosyn'},
#  'C0426675': {'tympanic'},
#  'C0578093': {'epigastric|tenderness', 'midepigastric tenderness'},
#  'C0234246': {'rebound'},
#  'C1955856': {'The ostomy'},
#  'C0182097': {'the ostomy bag'},
#  'C2711635': {'Guaiac all stools', 'Heme', 'guaiac', 'stool heme'},
#  'C0022885': {'Labs', 'laboratory studies'},
#  'C0203102': {'KUB'},
#  'C0577028': {'multiple dilated loops of small bowel'},
#  'C0019593': {'an H2 blocker'},
#  'C4039064': {'bowel rest'},
#  'C1829459': {'decompression'},
#  'C0592278': {'Zantac', 'is to'},
#  'C0037138': {'SIMETHICONE', 'Simethicone'},
#  'C0445204': {'preoperative'},
#  'C0023985': {'diverting ileostomy'},
#  'C0227388': {'left colon'},
#  'C0442805': {'increase', 'spikes'},
#  'C0267055': {'erosive esophagitis'},
#  'C0007203': {'CPR'},
#  'C0397419': {'defib', 'defibrillation'},
#  'C0017887': {'NITROGLYCERIN', 'NTG', 'nitroglycerin'},
#  'C0917801': {'insomnia'},
#  'C0018546': {'HALOPERIDOL', 'Haloperidol'},
#  'C0028978': {'OMEPRAZOLE', 'Omeprazole', 'omeprazole'},
#  'C0004147': {'ATENOLOL', 'Atenolol', 'atenolol'},
#  'C0018926': {'hematemesis'},
#  'C0005001': {'bph ( benign prostatic hypertrophy )'},
#  'C0020258': {'nph'},
#  'C0020255': {'hydrocephalus'},
#  'C0497327': {'dementia ( dementia )'},
#  'C0041296': {'TB'},
#  'C0006826': {'CA', 'cancer', 'malignancy'},
#  'C0014854': {'esophageal diverticulum'},
#  'C0151701': {'alveolar hemorrhage'},
#  'C0232077': {'aspirated blood'},
#  'C0358591': {'PPI'},
#  'C0301569': {'a soft mechanical diet', 'diet|soft-mechanical', 'soft diet'},
#  'C0262384': {'atypical chest pain'},
#  'C0003364': {'BP meds'},
#  'C3714636': {'pneuomonitis'},
#  'C0178879': {'obstructive uropathy'},
#  'C2919339': {'Her urine output', 'UOP', 'urine output'},
#  'C1970989': {'a Foley catheter',
#   'foley',
#   'her Foley',
#   'his Foley catheter',
#   'the Foley catheter'},
#  'C0582114': {'DNR'},
#  'C0150126': {'airway protection'},
#  'C0205161': {'Abnormal',
#   'abnormal',
#   'abnormali-ties',
#   'abnormality',
#   'decreased function'},
#  'C0239293': {'an esophageal bleed'},
#  'C0333307': {'non-bleeding|erosions', 'these erosions'},
#  'C0420266': {'Further testing',
#   'any further studies',
#   'further evaluation',
#   'further studies',
#   'further testing',
#   'further work up',
#   'further workup'},
#  'C0005558': {'A biopsy', 'Biopsy', 'biopsies', 'biopsy', 'de IIi/III'},
#  'C0205404': {'SERIOUS', 'serious'},
#  'C0687133': {'INTERACTION'},
#  'C0591585': {'HALDOL', 'Haldol'},
#  'C0021492': {'IM', 'IM injection'},
#  'C1720771': {'scrotal hydrocele'},
#  'C0230145': {'substernal'},
#  'C1261075': {'RLL', 'right lower lobe'},
#  'C0225756': {'upper lung field'},
#  'C0018188': {'granulomas'},
#  'C0227191': {'distal 1/3 of esophagus'},
#  'C0205400': {'thickened', 'thickening'},
#  'C0225692': {'alveolar'},
#  'C1265876': {'opacities', 'the opacities'},
#  'C0205207': {'cystic'},
#  'C2937230': {'hypodensities'},
#  'C0023884': {'liver'},
#  'C0205132': {'linear'},
#  'C0205113': {'circumfrencial'},
#  'C1959831': {'intra-esophageal ultrasound'},
#  'C0341117': {'erosions in the esophagus'},
#  'C0205555': {'special'},
#  'C0442808': {'increasing', 'increasingly'},
#  'C0724725': {'ZOLPIDEM TARTRATE'},
#  'C0041582': {'an ulcer', 'ulcer', 'ulceration'},
#  'C0014871': {'GE junction'},
#  'C0018305': {'GUAIFENESIN'},
#  'C0203075': {'barium enema'},
#  'C0003962': {'ascites'},
#  'C1828115': {'STAGE 3C|CARCINOMA OF THE OVARY',
#   'Stage 3C|carcinoma of the ovary',
#   'the 3C ovarian carcinoma'},
#  'C0020883': {'ileostomy'},
#  'C0010583': {'Cytoxan'},
#  'C0008838': {'Cisplatin'},
#  'C1706406': {'debulking',
#   'debulking of tumor',
#   'open debulking',
#   'tumor debulking'},
#  'C0404079': {'Total abdominal hysterectomy',
#   'a total abdominal hysterectomy/',
#   'atotal abdominal hysterectomy',
#   'total abdominal hysterectomy'},
#  'C0195495': {'bilateral salpingo-oophorectomy',
#   'bilateral salpingooophorectomy'},
#  'C0037995': {'splenectomy'},
#  'C0192775': {'a take down of the ileostomy'},
#  'C0400056': {'ileal cecal resection'},
#  'C0458084': {'MDR'},
#  'C0733688': {'VP 16'},
#  'C0162575': {'an embolectomy'},
#  'C0699194': {'Ativan'},
#  'C0065164': {'Lomotil'},
#  'C0577625': {'shellfish allergy'},
#  'C0571817': {'an Iodine allergy'},
#  'C1261467': {'weight'},
#  'C0002170': {'alopecia'},
#  'C0200633': {'ANC', 'a ANC', 'neutrophils', 'the absolute neutrophil count'},
#  'C2316467': {'packed red blood cell', 'packed red blood cells'},
#  'C0024467': {'a magnesium'},
#  'C3665472': {'chemo therapy', 'chemotherapy', 'her chemotherapy'},
#  'C0456081': {'adjustments'},
#  'C0562319': {'Cardiac examination',
#   'Heart exam',
#   'The heart examination',
#   'cardiac exam',
#   'cardiac studies'},
#  'C3164167': {'left upper quadrant tenderness'},
#  'C0750502': {'appreciable', 'significant'},
#  'C0205549': {'Serial', 'serial'},
#  'C0334361': {'PAPILLARY SEROUS CARCINOMA', 'papillary serous carcinoma'},
#  'C0555220': {'stenotic area|sigmoid'},
#  'C0227391': {'sigmoid'},
#  'C0444598': {'mid', 'midportion'},
#  'C0205170': {'well'},
#  'C0205249': {'healed'},
#  'C0549183': {'midline'},
#  'C0577123': {'abdominal scar'},
#  'C0230184': {'lower quadrant'},
#  'C1268768': {'Dentition very poor', 'poor dentition'},
#  'C0009068': {'Suture', 'sutured'},
#  'C0023418': {'leukemia'},
#  'C1827285': {'an entry wound'},
#  'C0332696': {'powder burn'},
#  'C0577816': {'The heart sounds'},
#  'C0577154': {'the bowel sounds'},
#  'C1828051': {'poor ability for abstract thinking'},
#  'C0702182': {'The extra ocular movements', 'the extra ocular movements'},
#  'C0587355': {'A panel of serum electrolytes'},
#  'C0043159': {'Blood coagulation times'},
#  'C0580937': {'A panel of serum enzymes'},
#  'C0430456': {'Standard 12 lead electrocardiogram',
#   'lation with a QT interval o'},
#  'C1997940': {'Nonspecific ST segment and T wave abnormalities'},
#  'C0043252': {'GUNSHOT WOUND',
#   'a gunshot wound',
#   'gunshot wound',
#   'gunshot wounds',
#   'his gunshot wound',
#   'the patient &apos;s gunshot wound'},
#  'C0204732': {'suicide precautions'},
#  'C0035260': {'2 point restraints'},
#  'C0581528': {'Close monitoring'},
#  'C0150270': {'his dosage regimen'},
#  'C1320527': {'intense psychiatric care'},
#  'C0699512': {', and Pe', 'Dilantin'},
#  'C0067044': {'Mylanta'},
#  'C0013395': {'Dyspepsia'},
#  'C0008783': {'Cimetidine'},
#  'C0277884': {'systolic blood pressure greater than 160 millemeters of Mercury'},
#  'C0018670': {'HEAD', 'head'},
#  'C0480203': {'SELF INFLICTED|WOUND',
#   'Self inflicted|wound',
#   'self inflicted|wound'},
#  'C0228232': {'right temporal head'},
#  'C0273239': {'head wound'},
#  'C0455204': {'homicidal ideation'},
#  'C0424000': {'suicidal|ideation'},
#  'C0228207': {'right parietal', 'right parietal region'},
#  'C1442861': {'bruising about the eyes'},
#  'C0423514': {'bruising|mastoid sinuses'},
#  'C1260880': {'fluid from|nose'},
#  'C0155540': {'fluid from|ears'},
#  'C1278213': {'toxic screen', 'toxicology screen'},
#  'C0420643': {'Serum toxic screen'},
#  'C0037304': {'skull fracture'},
#  'C0205101': {'external'},
#  'C0009938': {'contusion'},
#  'C0232320': {'anteroseptal myocardial infarction'},
#  'C0677546': {'old'},
#  'C1289919': {'IV fluids', 'intravenous fluid'},
#  'C0021440': {'infusion|intravenous'},
#  'C0542537': {'poor'},
#  'C1287078': {'R wave progression', 'R-waves'},
#  'C0200638': {'eos', 'eosinophils'},
#  'C0200641': {'basophils'},
#  'C0699440': {'LABETALOL HCL'},
#  'C0074554': {'SIMVASTATIN', 'simvastatin'},
#  'C0027996': {'NIACIN', 'VIT . B-3', 'VIT. B-3'},
#  'C3236097': {'NEPHROCAPS PO'},
#  'C0457987': {'Renal diet'},
#  'C0019004': {'HD', 'Hemodialysis', 'hemodialysis'},
#  'C0700053': {'IHSS'},
#  'C0022661': {'END STAGE RENAL DISEASE', 'ESRD'},
#  'C0017661': {'IgA nephropathy'},
#  'C0030163': {'his pacemaker', 'pacemaker'},
#  'C1704272': {'BPH'},
#  'C0040771': {'TURP'},
#  'C0018099': {'Gout', 'gout'},
#  'C0032739': {'positive PPD'},
#  'C0026266': {'MITRAL REGURGITATION',
#   'MR',
#   'Mitral regurgitation',
#   'mitral insufficiency',
#   'mitral regurgitation'},
#  'C0424605': {'developmental delay'},
#  'C1396002': {'&quot; raccoon eyes &quot;', 'raccoon eyes'},
#  'C0041657': {'loc', 'loss of consciousness'},
#  'C0013819': {'EEG', 'Electroencephalogram', 'electroencephalogram'},
#  'C0554757': {'carotid u / s', 'carotid ultrasound studies'},
#  'C0428861': {'fixed defect'},
#  'C0020835': {'IgA'},
#  'C1998174': {'nodal ablation'},
#  'C0021368': {'inflammation'},
#  'C1254541': {'INR', 'an INR', 'for'},
#  'C1096012': {'telemetry'},
#  'C0087086': {'a thrombus'},
#  'C0520863': {'abnormal diastolic function'},
#  'C0002726': {'amyloidosis'},
#  'C0201720': {'SPEP', 'an SPEP'},
#  'C0201888': {'ACE test'},
#  'C1261287': {'constrictive physiology', 'stenosis', 'stricture'},
#  'C0020651': {'orthostatic hypotension'},
#  'C0011946': {'DIALYSIS', 'dialysis'},
#  'C0022658': {'his renal disease'},
#  'C0523952': {'His troponins', 'Trop', 'troponins'},
#  'C0948089': {'ACS'},
#  'C0039070': {'syncope'},
#  'C0591301': {'COZAAR', 'cozaar'},
#  'C3875112': {'bleeding risk'},
#  'C0202230': {'TSH'},
#  'C2004480': {'a macrocytosis'},
#  'C0202252': {'His B12 level'},
#  'C0042847': {'B12 deficiency'},
#  'C0236663': {'EtOH WD', 'alcohol withdrawal'},
#  'C0156273': {'bladder diverticula'},
#  'C0203307': {'a follow up ultrasound'},
#  'C0201112': {'A c.difficile test'},
#  'C0085639': {'FALL', 'fall', 'falls'},
#  'C0547030': {'change of vision', 'visual changes'},
#  'C0151786': {'decreased strength',
#   'lantar f',
#   'muscle weakness',
#   'muscular weakness',
#   't that s'},
#  'C0018941': {'blood tests'},
#  'C0011560': {'amyloid'},
#  'C0935625': {'fat pad'},
#  'C0198500': {'abdominal|biopsy'},
#  'C0332185': {'Recent', 'recent'},
#  'C0430471': {'MIBI'},
#  'C0205343': {'reversible'},
#  'C0225910': {'inferolateral'},
#  'C0016540': {'forehead'},
#  'C0018944': {'hematoma'},
#  'C1720243': {'1+ edema'},
#  'C0441471': {'events'},
#  'C0085612': {'a ventricular response',
#   'moderate ventricular response',
#   'ventricular arrhythmia'},
#  'C0205081': {'moderate'},
#  'C0149721': {'LVH',
#   'ertrophy , which had been an',
#   'left ventricular hyper-trophy',
#   'left ventricular hypertrophy'},
#  'C0439744': {'c', 'concentric'},
#  'C0238705': {'LAE'},
#  'C0878544': {'cardiomyopathy'},
#  'C0201721': {'UPEP'},
#  'C0201910': {'Beta 2 microglobulin'},
#  'C0031117': {'a peripheral neuropathy', 'peripheral neuropathy'},
#  'C0229671': {'serum'},
#  'C0748283': {'complex renal cyst'},
#  'C0444507': {'incidental'},
#  'C1274040': {'findings'},
#  'C0015733': {'fecal'},
#  'C0023516': {'leukocytes'},
#  'C1524063': {'use'},
#  'C0203408': {'renal ultrasound', 'ultrasound|kidney'},
#  'C0412547': {'ultrasound|bladder'},
#  'C3887499': {'kidney cyst', 'renal cyst'},
#  'C0722621': {'PHOSLO'},
#  'C0717537': {'CALCIUM ACETATE'},
#  'C3223929': {'FLOVENT HFA'},
#  'C0117996': {'FLUTICASONE PROPIONATE'},
#  'C0126174': {'LOSARTAN'},
#  'C0306965': {'NEPHROCAPS'},
#  'C0042397': {'pressors'},
#  'C0017628': {'GLYBURIDE', 'Micronase'},
#  'C0022957': {'LACTULOSE', 'Lactulose', 'lactulose'},
#  'C3232296': {'SENNA TABLETS'},
#  'C0577089': {'gas'},
#  'C0235309': {'upset stomach'},
#  'C0039286': {'TAMOXIFEN', 'tamoxifen'},
#  'C1271155': {'LEVOFLOXACIN PO'},
#  'C0079589': {'TAMOXIFEN CITRATE'},
#  'C0979545': {'PILOCARPINE 4% SOLUTION'},
#  'C4257080': {'FLONASE ( FLUTICASONE NASAL SPRAY )'},
#  'C0008809': {'Ciprofloxacin', 'ciprofloxacin'},
#  'C0311131': {'tube feeds'},
#  'C0719097': {'CALCIUM CARB + D'},
#  'C0007562': {'CEFUROXIME', 'cefuroxime'},
#  'C0591139': {'Bactrim'},
#  'C0042109': {'hives'},
#  'C0007537': {'Ceclor'},
#  'C0055856': {'CLARITHROMYCIN', 'Clarythro'},
#  'C0032371': {'poliomyelitis'},
#  'C0006142': {'breast CA'},
#  'C2911574': {'vent dependent'},
#  'C0559400': {'an iron lung', 'iron lung'},
#  'C0018932': {'BRBPR', 'bright red blood per rectum'},
#  'C0025222': {'dark stools per rectum', 'melena'},
#  'C0013428': {'dysuria'},
#  'C0232694': {'hyperactive bowel sounds'},
#  'C0000731': {'Her abd distention', 'abd distention', 'abdominal distention'},
#  'C0427198': {'guarding'},
#  'C4019039': {'ileus'},
#  ...}

# %%
#### Training Phase  ####
print(train_df.head())

# we tokenize the sentences
sentences = train_df.original_sentence
st = train_df.position_start
end = train_df.position_end

tokenizer = config.TOKENIZER
mask_token = tokenizer.tokenize("[MASK]")

tokenized_pre = tokenizer.tokenize(sentences[0][:st[0]])
tokenized_post = tokenizer.tokenize(sentences[0][end[0]:])
tokenized = tokenized_pre + (mask_token) + tokenized_post

ids = tokenizer.convert_tokens_to_ids(tokenized)
target_position = len(tokenized_pre)

# %%
tokenizer = config.TOKENIZER
mask_token = tokenizer.tokenize("[MASK]")

input_ids = []
input_target_positions = []
labels = []
enc_label = preprocessing.LabelEncoder()

for index in tqdm(train_df.index):
    row = train_df.loc[index]
    if row['cui'] in train_single_cui:
        continue
    sentence = row['original_sentence']
    st = row['position_start']
    end = row['position_end']

    tokenized_pre = tokenizer.tokenize(sentence[:st])
    target_position = len(tokenized_pre)
    if target_position > config.MAX_LEN//2:
        tokenized_pre = tokenized_pre[-config.MAX_LEN//2:]
        target_position = len(tokenized_pre)

    tokenized_post = tokenizer.tokenize(sentence[end+1:])
    tokenized = tokenized_pre + (mask_token) + tokenized_post
    ids = tokenizer.convert_tokens_to_ids(tokenized)
    ids = ids[(len(ids)-config.MAX_LEN)//2+1 : (len(ids)+config.MAX_LEN)//2-1]
    input_ids.append(ids)
    input_target_positions.append(target_position)
    labels.append(row['cui'])
labels = enc_label.fit_transform(labels)

# %%
from keras.preprocessing.sequence import pad_sequences
input_ids = pad_sequences(input_ids, maxlen=config.MAX_LEN, dtype="long", value=0, truncating="post", padding="post")

# %%
attention_masks = []
for sent in input_ids:
    att_mask = [int(token_id > 0) for token_id in sent]
    attention_masks.append(att_mask)

from sklearn.model_selection import train_test_split

train_inputs, validation_inputs, train_position, validation_position, train_labels, validation_labels = train_test_split(input_ids, input_target_positions, labels, random_state=2020, test_size=0.1)
train_masks, validation_masks, _, _ = train_test_split(attention_masks, labels, random_state=2020, test_size=0.1)

# %%
train_inputs = torch.tensor(train_inputs)
validation_inputs = torch.tensor(validation_inputs)

train_position = torch.tensor(train_position)
validation_position = torch.tensor(validation_position)

train_labels = torch.tensor(train_labels)
validation_labels = torch.tensor(validation_labels)

train_masks = torch.tensor(train_masks)
validation_masks = torch.tensor(validation_masks)

# %%
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler

# Create the DataLoader for our training set.
train_data = TensorDataset(train_inputs, train_masks, train_labels, train_position)
train_sampler = RandomSampler(train_data)
train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=config.BATCH_SIZE)

# Create the DataLoader for our validation set.
validation_data = TensorDataset(validation_inputs, validation_masks, validation_labels, validation_position)
validation_sampler = SequentialSampler(validation_data)
validation_dataloader = DataLoader(validation_data, sampler=validation_sampler, batch_size=config.BATCH_SIZE)

# %%
from transformers import BertForSequenceClassification, AdamW, BertConfig

Load BertForSequenceClassification, the pretrained BERT model with a single 
linear classification layer on top. 
model = BertForSequenceClassification.from_pretrained(
    "bert-base-uncased", # Use the 12-layer BERT model, with an uncased vocab.
    num_labels = len(enc_label.classes_), # The number of output labels--2 for binary classification.
                    # You can increase this for multi-class tasks.   
    output_attentions = False, # Whether the model returns attentions weights.
    output_hidden_states = False, # Whether the model returns all hidden-states.
)
# Tell pytorch to run this model on the GPU.
_ = model.cuda()

# %%
optimizer = AdamW(model.parameters(),
                  lr = 2e-5, # args.learning_rate - default is 5e-5, our notebook had 2e-5
                  eps = 1e-8 # args.adam_epsilon  - default is 1e-8.
                )
from transformers import get_linear_schedule_with_warmup
epochs = config.EPOCHS
total_steps = len(train_dataloader) * epochs
scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps = 0,
                                            num_training_steps = total_steps)

import numpy as np
import time
import datetime
import random

def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

def format_time(elapsed):
    elapsed_rounded = int(round((elapsed)))
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %%
seed_val = 42

random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# Store the average loss after each epoch so we can plot them.
loss_values = []
for epoch_i in range(0, epochs):
    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')

    t0 = time.time()
    total_loss = 0
    model.train()
    for step, batch in enumerate(train_dataloader):
        if step % 40 == 0 and not step == 0:
            elapsed = format_time(time.time() - t0)
            print('  Batch {:>5,}  of  {:>5,}.    Elapsed: {:}.'.format(step, len(train_dataloader), elapsed))
        b_input_ids = batch[0].to(device)
        b_input_mask = batch[1].to(device)
        b_labels = batch[2].to(device)
        b_pos = batch[3].to(device)

        model.zero_grad()        

        outputs = model(b_input_ids, 
                    token_type_ids=None
                    )
        loss = outputs[0]
        total_loss += loss.item()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        scheduler.step()
    avg_train_loss = total_loss / len(train_dataloader)            
    loss_values.append(avg_train_loss)
    print("")
    print("  Average training loss: {0:.2f}".format(avg_train_loss))
    print("  Training epcoh took: {:}".format(format_time(time.time() - t0)))
    ########################################3
    print("")
    print("Running Validation...")
    t0 = time.time()
    model.eval()
    eval_loss, eval_accuracy = 0, 0
    nb_eval_steps, nb_eval_examples = 0, 0
    for batch in validation_dataloader:
        batch = tuple(t.to(device) for t in batch)
        b_input_ids, b_input_mask, b_labels, b_pos = batch
        with torch.no_grad():        
            outputs = model(b_input_ids, 
                            token_type_ids=None, 
                            attention_mask=b_input_mask)
        logits = outputs[0]
        logits = logits.detach().cpu().numpy()
        label_ids = b_labels.to('cpu').numpy()
        tmp_eval_accuracy = flat_accuracy(logits, label_ids)
        eval_accuracy += tmp_eval_accuracy
        nb_eval_steps += 1
    print("  Accuracy: {0:.2f}".format(eval_accuracy/nb_eval_steps))
    print("  Validation took: {:}".format(format_time(time.time() - t0)))

print("")
print("Training complete!")

# %%
model.eval()
predictions , true_labels = [], []
prediction_dataloader = train_dataloader
for batch in prediction_dataloader:
    batch = tuple(t.to(device) for t in batch)
    b_input_ids, b_input_mask, b_labels, b_pos = batch
    with torch.no_grad():
        outputs = model(b_input_ids, token_type_ids=None, 
                      attention_mask=b_input_mask)
    logits = outputs[0]
    logits = logits.detach().cpu().numpy()
    label_ids = b_labels.to('cpu').numpy()
    predictions.append(logits)
    true_labels.append(label_ids)

print('DONE.')

# %%
from sklearn.metrics import accuracy_score
flat_predictions = [item for sublist in predictions for item in sublist]
flat_predictions = np.argmax(flat_predictions, axis=1).flatten()
flat_true_labels = [item for sublist in true_labels for item in sublist]

print("Accuracy: ", accuracy_score(flat_true_labels, flat_predictions))

# %% [markdown]
# # ignore below

# %%
# load test data
test_data, _ = reading_files_test("C:/Users/monil/Desktop/BMI 598 - NLP/Project/Clinical-Entity-Normalization/testing")
test_df = create_dataset(test_data)
# Out:
# Total number of files:  50

# %%
test_df.mention
# Out:
# 0                     HIV positive
# 1         left upper quadrant pain
# 2                           nausea
# 3                         vomiting
# 4        a long-standing complaint
#                    ...
# 7081                   prostate CA
# 7082    HISTORY OF PRESENT ILLNESS
# 7083        Niferex 150 milligrams
# 7084                   SIGNIFICANT
# 7085                      PROBLEMS
# Name: mention, Length: 7086, dtype: object
